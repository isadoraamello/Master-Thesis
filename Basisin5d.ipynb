# %% [markdown]
# <a href="https://colab.research.google.com/github/isadoraamello/Master-Thesis/blob/main/Basisin5d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5 dimensions, using measurements defined by the pentagon geometry, complex phases and 4 rounds of measurements for Alice

# %%
import numpy as np
from itertools import product
from itertools import permutations

# Set dimension
d = 5  # working in a 5-level system

# Useful functions for ket and ket ⊗ ket
def Ket(i):
    """Create a basis vector |i⟩ (0-indexed)"""
    return np.eye(1, d, i).flatten()  # More efficient than UnitVector

def ket(i, j):
    """Create a product state |i⟩ ⊗ |j⟩"""
    return np.kron(Ket(i), Ket(j))

def OuterProduct(psi, phi):
    """Create outer product |ψ⟩⟨φ|"""
    return np.outer(psi, phi.conj())

# Post measurement States
# x=1
Psi11 = 1/np.sqrt(2)*(Ket(0) + Ket(1))
Psi21 = 1/np.sqrt(2)*(Ket(0) - Ket(1))
Psi31 = 1/np.sqrt(2)*(Ket(1) + Ket(2))
Psi41 = 1/np.sqrt(2)*(Ket(1) - Ket(2))
Psi51 = 1/np.sqrt(2)*(Ket(2) + Ket(3))
Psi61 = 1/np.sqrt(2)*(Ket(2) - Ket(3))
Psi71 = 1/np.sqrt(2)*(Ket(3) + Ket(4))
Psi81 = 1/np.sqrt(2)*(Ket(3) - Ket(4))
Psi91 = 1/np.sqrt(2)*(Ket(0) + Ket(4))
Psi101 = 1/np.sqrt(2)*(Ket(0) - Ket(4))

# x=2
Psi12 = 1/np.sqrt(2)*(Ket(0) + 1j*Ket(1))
Psi22 = 1/np.sqrt(2)*(Ket(0) - 1j*Ket(1))
Psi32 = 1/np.sqrt(2)*(Ket(1) + 1j*Ket(2))
Psi42 = 1/np.sqrt(2)*(Ket(1) - 1j*Ket(2))
Psi52 = 1/np.sqrt(2)*(Ket(2) + 1j*Ket(3))
Psi62 = 1/np.sqrt(2)*(Ket(2) - 1j*Ket(3))
Psi72 = 1/np.sqrt(2)*(Ket(3) + 1j*Ket(4))
Psi82 = 1/np.sqrt(2)*(Ket(3) - 1j*Ket(4))
Psi92 = 1/np.sqrt(2)*(Ket(0) + 1j*Ket(4))
Psi102 = 1/np.sqrt(2)*(Ket(0) - 1j*Ket(4))


# x=3
Psi13 = 1/np.sqrt(2)*(Ket(0) + Ket(2))
Psi23 = 1/np.sqrt(2)*(Ket(0) - Ket(2))
Psi33 = 1/np.sqrt(2)*(Ket(2) + Ket(4))
Psi43 = 1/np.sqrt(2)*(Ket(2) - Ket(4))
Psi53 = 1/np.sqrt(2)*(Ket(1) + Ket(4))
Psi63 = 1/np.sqrt(2)*(Ket(1) - Ket(4))
Psi73 = 1/np.sqrt(2)*(Ket(1) + Ket(3))
Psi83 = 1/np.sqrt(2)*(Ket(1) - Ket(3))
Psi93 = 1/np.sqrt(2)*(Ket(0) + Ket(3))
Psi103 = 1/np.sqrt(2)*(Ket(0) - Ket(3))

# x=4
Psi14 = 1/np.sqrt(2)*(Ket(0) + 1j*Ket(2))
Psi24 = 1/np.sqrt(2)*(Ket(0) - 1j*Ket(2))
Psi34 = 1/np.sqrt(2)*(Ket(2) + 1j*Ket(4))
Psi44 = 1/np.sqrt(2)*(Ket(2) - 1j*Ket(4))
Psi54 = 1/np.sqrt(2)*(Ket(1) + 1j*Ket(4))
Psi64 = 1/np.sqrt(2)*(Ket(1) - 1j*Ket(4))
Psi74 = 1/np.sqrt(2)*(Ket(1) + 1j*Ket(3))
Psi84 = 1/np.sqrt(2)*(Ket(1) - 1j*Ket(3))
Psi94 = 1/np.sqrt(2)*(Ket(0) + 1j*Ket(3))
Psi104 = 1/np.sqrt(2)*(Ket(0) - 1j*Ket(3))

# %%
states = {
    "x1": [
        ("A11", Psi11), ("A21", Psi21), ("A31", Psi31), ("A41", Psi41),
        ("A51", Psi51), ("A61", Psi61), ("A71", Psi71), ("A81", Psi81),
        ("A91", Psi91), ("A101", Psi101)
    ],
    "x2": [
        ("A12", Psi12), ("A22", Psi22), ("A32", Psi32), ("A42", Psi42),
        ("A52", Psi52), ("A62", Psi62), ("A72", Psi72), ("A82", Psi82),
        ("A92", Psi92), ("A102", Psi102)
    ],
    "x3": [
        ("A13", Psi13), ("A23", Psi23), ("A33", Psi33), ("A43", Psi43),
        ("A53", Psi53), ("A63", Psi63), ("A73", Psi73), ("A83", Psi83),
        ("A93", Psi93), ("A103", Psi103)
    ],
    "x4": [
        ("A14", Psi14), ("A24", Psi24), ("A34", Psi34), ("A44", Psi44),
        ("A54", Psi54), ("A64", Psi64), ("A74", Psi74), ("A84", Psi84),
        ("A94", Psi94), ("A104", Psi104)
    ]
}

# %%
def density_matrix(psi):
    return OuterProduct(psi, psi)

# %%
# Bob's measurements
# y=1
Phi11 = 1/2*(-Ket(0)+Ket(1)+Ket(2)-Ket(3))
Phi21 = 1/2*(Ket(0)-1j*Ket(1)+Ket(2)-1j*Ket(3))
Phi31 = 1/2*(Ket(0)+Ket(1)-Ket(2)-Ket(3))
Phi41 = 1/2*(Ket(0)+1j*Ket(1)+Ket(2)+1j*Ket(3))
Phi51 = Ket(4)

# %%
# Bob's measurements
# y=2
Phi12 = 1/2*(Ket(0)-Ket(1)+Ket(2)+Ket(3))
Phi22 = 1/2*(-Ket(0)+1j*Ket(1)+Ket(2)+Ket(3))
Phi32 = 1/2*(Ket(0)-Ket(1)-Ket(2)+Ket(3))
Phi42 = 1/2*(-Ket(0)+Ket(1)+1j*Ket(2)+Ket(3))
Phi52 = Ket(4)

# %%
computational_basis = [
    ("|0>", Ket(0)),
    ("|1>", Ket(1)),
    ("|2>", Ket(2)),
    ("|3>", Ket(3)),
    ("|4>", Ket(4))
]

all_povm_orders = list(permutations(computational_basis))

# %%
povm_kets1 = [Phi11, Phi21, Phi31, Phi41, Phi51]
povm_kets2 = [Phi12, Phi22, Phi32, Phi42, Phi52]
povm_kets3 = [Phi13, Phi23, Phi33, Phi43, Phi53]

# %%
def is_antidistinguishable(vectors, povm_kets, tol=1e-10):
    """
    Checks <psi_i | phi_i> = 0 for each pair.
    vectors: list of |psi_i>
    povm_kets: list of |phi_i>
    """

    for psi, phi in zip(vectors, povm_kets):

        overlap = np.vdot(phi, psi)  # <phi|psi>

        if abs(overlap) > tol:
            return False

    return True

# %%
all_combinations = product(
    states["x1"],
    states["x2"],
    states["x3"],
    states["x4"]
)

for povm in all_povm_orders:

    povm_labels = [n for n, _ in povm]
    povm_vectors = [v for _, v in povm]

    valid_combinations = []

    for combo in all_combinations:

        names = [n for n, _ in combo]
        vectors = [v for _, v in combo]

        if is_antidistinguishable(vectors, povm_vectors):
            valid_combinations.append(names)

    #print("\nPOVM ordering:", povm_labels)
    print("Number of valid combinations:",
          len(valid_combinations))

    #for c in valid_combinations:
        #print(c)

    # Regenerate combinations for next POVM
    all_combinations = product(
        states["x1"],
        states["x2"],
        states["x3"],
        states["x4"]
    )
# Out:
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296
# Number of valid combinations: 1296

# %%
remaining_combinations = list(product(
    states["x1"],
    states["x2"],
    states["x3"],
    states["x4"]
))

for povm in all_povm_orders:

    povm_labels = [n for n, _ in povm]
    povm_vectors = [v for _, v in povm]

    valid_combinations = []
    new_remaining = []

    for combo in remaining_combinations:

        names = [n for n, _ in combo]
        vectors = [v for _, v in combo]

        if is_antidistinguishable(vectors, povm_vectors):

            valid_combinations.append(names)

        else:
            new_remaining.append(combo)

    # Update remaining combinations
    remaining_combinations = new_remaining

    print("\nPOVM ordering:", povm_labels)

    print("Number of valid combinations:",
          len(valid_combinations))

    #for c in valid_combinations:
        #print(c)

    print("Remaining combinations:",
          len(remaining_combinations))
# Out:
# POVM ordering: ['|0>', '|1>', '|2>', '|3>', '|4>']
# Number of valid combinations: 1296
# Remaining combinations: 8704
#
# POVM ordering: ['|0>', '|1>', '|2>', '|4>', '|3>']
# Number of valid combinations: 864
# Remaining combinations: 7840
#
# POVM ordering: ['|0>', '|1>', '|3>', '|2>', '|4>']
# Number of valid combinations: 864
# Remaining combinations: 6976
#
# POVM ordering: ['|0>', '|1>', '|3>', '|4>', '|2>']
# Number of valid combinations: 288
# Remaining combinations: 6688
#
# POVM ordering: ['|0>', '|1>', '|4>', '|2>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 6688
#
# POVM ordering: ['|0>', '|1>', '|4>', '|3>', '|2>']
# Number of valid combinations: 144
# Remaining combinations: 6544
#
# POVM ordering: ['|0>', '|2>', '|1>', '|3>', '|4>']
# Number of valid combinations: 528
# Remaining combinations: 6016
#
# POVM ordering: ['|0>', '|2>', '|1>', '|4>', '|3>']
# Number of valid combinations: 288
# Remaining combinations: 5728
#
# POVM ordering: ['|0>', '|2>', '|3>', '|1>', '|4>']
# Number of valid combinations: 144
# Remaining combinations: 5584
#
# POVM ordering: ['|0>', '|2>', '|3>', '|4>', '|1>']
# Number of valid combinations: 48
# Remaining combinations: 5536
#
# POVM ordering: ['|0>', '|2>', '|4>', '|1>', '|3>']
# Number of valid combinations: 144
# Remaining combinations: 5392
#
# POVM ordering: ['|0>', '|2>', '|4>', '|3>', '|1>']
# Number of valid combinations: 48
# Remaining combinations: 5344
#
# POVM ordering: ['|0>', '|3>', '|1>', '|2>', '|4>']
# Number of valid combinations: 432
# Remaining combinations: 4912
#
# POVM ordering: ['|0>', '|3>', '|1>', '|4>', '|2>']
# Number of valid combinations: 144
# Remaining combinations: 4768
#
# POVM ordering: ['|0>', '|3>', '|2>', '|1>', '|4>']
# Number of valid combinations: 336
# Remaining combinations: 4432
#
# POVM ordering: ['|0>', '|3>', '|2>', '|4>', '|1>']
# Number of valid combinations: 144
# Remaining combinations: 4288
#
# POVM ordering: ['|0>', '|3>', '|4>', '|1>', '|2>']
# Number of valid combinations: 48
# Remaining combinations: 4240
#
# POVM ordering: ['|0>', '|3>', '|4>', '|2>', '|1>']
# Number of valid combinations: 48
# Remaining combinations: 4192
#
# POVM ordering: ['|0>', '|4>', '|1>', '|2>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 4192
#
# POVM ordering: ['|0>', '|4>', '|1>', '|3>', '|2>']
# Number of valid combinations: 96
# Remaining combinations: 4096
#
# POVM ordering: ['|0>', '|4>', '|2>', '|1>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 4096
#
# POVM ordering: ['|0>', '|4>', '|2>', '|3>', '|1>']
# Number of valid combinations: 96
# Remaining combinations: 4000
#
# POVM ordering: ['|0>', '|4>', '|3>', '|1>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 4000
#
# POVM ordering: ['|0>', '|4>', '|3>', '|2>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 4000
#
# POVM ordering: ['|1>', '|0>', '|2>', '|3>', '|4>']
# Number of valid combinations: 432
# Remaining combinations: 3568
#
# POVM ordering: ['|1>', '|0>', '|2>', '|4>', '|3>']
# Number of valid combinations: 288
# Remaining combinations: 3280
#
# POVM ordering: ['|1>', '|0>', '|3>', '|2>', '|4>']
# Number of valid combinations: 288
# Remaining combinations: 2992
#
# POVM ordering: ['|1>', '|0>', '|3>', '|4>', '|2>']
# Number of valid combinations: 96
# Remaining combinations: 2896
#
# POVM ordering: ['|1>', '|0>', '|4>', '|2>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 2896
#
# POVM ordering: ['|1>', '|0>', '|4>', '|3>', '|2>']
# Number of valid combinations: 48
# Remaining combinations: 2848
#
# POVM ordering: ['|1>', '|2>', '|0>', '|3>', '|4>']
# Number of valid combinations: 304
# Remaining combinations: 2544
#
# POVM ordering: ['|1>', '|2>', '|0>', '|4>', '|3>']
# Number of valid combinations: 192
# Remaining combinations: 2352
#
# POVM ordering: ['|1>', '|2>', '|3>', '|0>', '|4>']
# Number of valid combinations: 96
# Remaining combinations: 2256
#
# POVM ordering: ['|1>', '|2>', '|3>', '|4>', '|0>']
# Number of valid combinations: 64
# Remaining combinations: 2192
#
# POVM ordering: ['|1>', '|2>', '|4>', '|0>', '|3>']
# Number of valid combinations: 96
# Remaining combinations: 2096
#
# POVM ordering: ['|1>', '|2>', '|4>', '|3>', '|0>']
# Number of valid combinations: 32
# Remaining combinations: 2064
#
# POVM ordering: ['|1>', '|3>', '|0>', '|2>', '|4>']
# Number of valid combinations: 0
# Remaining combinations: 2064
#
# POVM ordering: ['|1>', '|3>', '|0>', '|4>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 2064
#
# POVM ordering: ['|1>', '|3>', '|2>', '|0>', '|4>']
# Number of valid combinations: 0
# Remaining combinations: 2064
#
# POVM ordering: ['|1>', '|3>', '|2>', '|4>', '|0>']
# Number of valid combinations: 32
# Remaining combinations: 2032
#
# POVM ordering: ['|1>', '|3>', '|4>', '|0>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 2032
#
# POVM ordering: ['|1>', '|3>', '|4>', '|2>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 2032
#
# POVM ordering: ['|1>', '|4>', '|0>', '|2>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 2032
#
# POVM ordering: ['|1>', '|4>', '|0>', '|3>', '|2>']
# Number of valid combinations: 32
# Remaining combinations: 2000
#
# POVM ordering: ['|1>', '|4>', '|2>', '|0>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 2000
#
# POVM ordering: ['|1>', '|4>', '|2>', '|3>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 2000
#
# POVM ordering: ['|1>', '|4>', '|3>', '|0>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 2000
#
# POVM ordering: ['|1>', '|4>', '|3>', '|2>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 2000
#
# POVM ordering: ['|2>', '|0>', '|1>', '|3>', '|4>']
# Number of valid combinations: 432
# Remaining combinations: 1568
#
# POVM ordering: ['|2>', '|0>', '|1>', '|4>', '|3>']
# Number of valid combinations: 288
# Remaining combinations: 1280
#
# POVM ordering: ['|2>', '|0>', '|3>', '|1>', '|4>']
# Number of valid combinations: 144
# Remaining combinations: 1136
#
# POVM ordering: ['|2>', '|0>', '|3>', '|4>', '|1>']
# Number of valid combinations: 48
# Remaining combinations: 1088
#
# POVM ordering: ['|2>', '|0>', '|4>', '|1>', '|3>']
# Number of valid combinations: 144
# Remaining combinations: 944
#
# POVM ordering: ['|2>', '|0>', '|4>', '|3>', '|1>']
# Number of valid combinations: 48
# Remaining combinations: 896
#
# POVM ordering: ['|2>', '|1>', '|0>', '|3>', '|4>']
# Number of valid combinations: 176
# Remaining combinations: 720
#
# POVM ordering: ['|2>', '|1>', '|0>', '|4>', '|3>']
# Number of valid combinations: 128
# Remaining combinations: 592
#
# POVM ordering: ['|2>', '|1>', '|3>', '|0>', '|4>']
# Number of valid combinations: 48
# Remaining combinations: 544
#
# POVM ordering: ['|2>', '|1>', '|3>', '|4>', '|0>']
# Number of valid combinations: 32
# Remaining combinations: 512
#
# POVM ordering: ['|2>', '|1>', '|4>', '|0>', '|3>']
# Number of valid combinations: 48
# Remaining combinations: 464
#
# POVM ordering: ['|2>', '|1>', '|4>', '|3>', '|0>']
# Number of valid combinations: 16
# Remaining combinations: 448
#
# POVM ordering: ['|2>', '|3>', '|0>', '|1>', '|4>']
# Number of valid combinations: 144
# Remaining combinations: 304
#
# POVM ordering: ['|2>', '|3>', '|0>', '|4>', '|1>']
# Number of valid combinations: 64
# Remaining combinations: 240
#
# POVM ordering: ['|2>', '|3>', '|1>', '|0>', '|4>']
# Number of valid combinations: 112
# Remaining combinations: 128
#
# POVM ordering: ['|2>', '|3>', '|1>', '|4>', '|0>']
# Number of valid combinations: 80
# Remaining combinations: 48
#
# POVM ordering: ['|2>', '|3>', '|4>', '|0>', '|1>']
# Number of valid combinations: 16
# Remaining combinations: 32
#
# POVM ordering: ['|2>', '|3>', '|4>', '|1>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 32
#
# POVM ordering: ['|2>', '|4>', '|0>', '|1>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 32
#
# POVM ordering: ['|2>', '|4>', '|0>', '|3>', '|1>']
# Number of valid combinations: 32
# Remaining combinations: 0
#
# POVM ordering: ['|2>', '|4>', '|1>', '|0>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|2>', '|4>', '|1>', '|3>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|2>', '|4>', '|3>', '|0>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|2>', '|4>', '|3>', '|1>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|0>', '|1>', '|2>', '|4>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|0>', '|1>', '|4>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|0>', '|2>', '|1>', '|4>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|0>', '|2>', '|4>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|0>', '|4>', '|1>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|0>', '|4>', '|2>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|1>', '|0>', '|2>', '|4>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|1>', '|0>', '|4>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|1>', '|2>', '|0>', '|4>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|1>', '|2>', '|4>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|1>', '|4>', '|0>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|1>', '|4>', '|2>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|2>', '|0>', '|1>', '|4>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|2>', '|0>', '|4>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|2>', '|1>', '|0>', '|4>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|2>', '|1>', '|4>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|2>', '|4>', '|0>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|2>', '|4>', '|1>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|4>', '|0>', '|1>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|4>', '|0>', '|2>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|4>', '|1>', '|0>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|4>', '|1>', '|2>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|4>', '|2>', '|0>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|3>', '|4>', '|2>', '|1>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|0>', '|1>', '|2>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|0>', '|1>', '|3>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|0>', '|2>', '|1>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|0>', '|2>', '|3>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|0>', '|3>', '|1>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|0>', '|3>', '|2>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|1>', '|0>', '|2>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|1>', '|0>', '|3>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|1>', '|2>', '|0>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|1>', '|2>', '|3>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|1>', '|3>', '|0>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|1>', '|3>', '|2>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|2>', '|0>', '|1>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|2>', '|0>', '|3>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|2>', '|1>', '|0>', '|3>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|2>', '|1>', '|3>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|2>', '|3>', '|0>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|2>', '|3>', '|1>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|3>', '|0>', '|1>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|3>', '|0>', '|2>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|3>', '|1>', '|0>', '|2>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|3>', '|1>', '|2>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|3>', '|2>', '|0>', '|1>']
# Number of valid combinations: 0
# Remaining combinations: 0
#
# POVM ordering: ['|4>', '|3>', '|2>', '|1>', '|0>']
# Number of valid combinations: 0
# Remaining combinations: 0
